# %%
import pandas as pd

# %%
qa_data = pd.read_csv("orion_analytics_qa.csv")

# %%
qa_data
# Out:
#                                              question  \
# 0                   When was Orion Analytics founded?
# 1       What was the company’s total revenue in 2024?
# 2   Which region contributed the most revenue in 2...
# 3   What percentage of total revenue came from Eur...
# 4        How much did operating expenses increase by?
# 5                What was Orion’s net profit in 2024?
# 6              Name Orion’s three main product lines.
# 7            Which product was introduced in 2024 Q2?
# 8   How much revenue did Orion Guard generate in i...
# 9      By what percentage did the R&D AI team expand?
# 10  Which university did Orion partner with for re...
# 11  What is the purpose of the Green Compute initi...
# 12  What was the reduction in carbon emissions ach...
# 13  Who were the two new board members added in 2024?
# 14  What areas of AI research did the company focu...
#
#                                                answer
# ...

# %%
rag_endpint = "http://localhost:8000/rag/query"
